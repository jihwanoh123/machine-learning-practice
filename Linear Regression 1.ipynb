# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a40c83e174a8> in <module>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from sklearn import linear_model
#
# ~/anaconda/lib/python3.6/site-packages/sklearn/__init__.py in <module>()
#      55 else:
#      56     from . import __check_build
# ---> 57     from .base import clone
#      58     __check_build  # avoid flakes unused variable error
#      59
#
# ~/anaconda/lib/python3.6/site-packages/sklearn/base.py in <module>()
#      10 from scipy import sparse
#      11 from .externals import six
# ---> 12 from .utils.fixes import signature
#      13 from .utils.deprecation import deprecated
#      14 from .exceptions import ChangedBehaviorWarning as _ChangedBehaviorWarning
#
# ~/anaconda/lib/python3.6/site-packages/sklearn/utils/__init__.py in <module>()
#       9
#      10 from .murmurhash import murmurhash3_32
# ---> 11 from .validation import (as_float_array,
#      12                          assert_all_finite,
#      13                          check_random_state, column_or_1d, check_array,
#
# ~/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py in <module>()
#      16
#      17 from ..externals import six
# ---> 18 from ..utils.fixes import signature
#      19 from .deprecation import deprecated
#      20 from ..exceptions import DataConversionWarning as _DataConversionWarning
#
# ~/anaconda/lib/python3.6/site-packages/sklearn/utils/fixes.py in <module>()
#     401         return .5 * (count[dense] + count[dense - 1] + 1)
#     402 else:
# --> 403     from scipy.stats import rankdata
#     404
#     405
#
# ~/anaconda/lib/python3.6/site-packages/scipy/stats/__init__.py in <module>()
#     342 from __future__ import division, print_function, absolute_import
#     343
# --> 344 from .stats import *
#     345 from .distributions import *
#     346 from .morestats import *
#
# ~/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py in <module>()
#     174 import scipy.linalg as linalg
#     175 import numpy as np
# --> 176 from . import distributions
#     177 from . import mstats_basic
#     178 from ._distn_infrastructure import _lazywhere
#
# ~/anaconda/lib/python3.6/site-packages/scipy/stats/distributions.py in <module>()
#      11                                     rv_frozen)
#      12
# ---> 13 from . import _continuous_distns
#      14 from . import _discrete_distns
#      15
#
# ~/anaconda/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py in <module>()
#      15                            inv_boxcox, inv_boxcox1p, erfc, chndtr, chndtrix,
#      16                            i0, i1, ndtr as _norm_cdf, log_ndtr as _norm_logcdf)
# ---> 17 from scipy._lib._numpy_compat import broadcast_to
#      18
#      19 from numpy import (where, arange, putmask, ravel, shape,
#
# ~/anaconda/lib/python3.6/site-packages/scipy/_lib/_numpy_compat.py in <module>()
#       8
#       9 import numpy as np
# ---> 10 from numpy.testing.nosetester import import_nose
#      11
#      12 from scipy._lib._version import NumpyVersion
#
# ModuleNotFoundError: No module named 'numpy.testing.nosetester'

# %%
#Read
df=pd.read_csv('homeprices.csv')

# %%
#First few
df.head()
# Out:
#               area  bedrooms        age          price
# count     6.000000   5.00000   6.000000       6.000000
# mean   3416.666667   4.20000  16.500000  648333.333333
# std     587.934237   1.30384   8.288546  109117.673484
# min    2600.000000   3.00000   8.000000  550000.000000
# 25%    3050.000000   3.00000   9.750000  572500.000000
# 50%    3400.000000   4.00000  16.500000  602500.000000
# 75%    3900.000000   5.00000  19.500000  722500.000000
# max    4100.000000   6.00000  30.000000  810000.000000

# %%
#Save the linear regression data
reg=linear_model.LinearRegression()

# %%
#Fit the data
reg.fit(df[['area']],df.price)

# %%
#Predict y-value for a given x val
reg.predict(3300)

# %%
# slope
reg.coef_
# Out:
# array([ 167.30954677])

# %%
reg.intercept_
# Out:
# 76692.381870781071

# %%
import matplotlib.pyplot as plt
plt.xlabel('area')
plt.ylabel('prices')
# %matplotlib inline
plt.scatter(df.area,df.prices)



# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
#Generate scatter plot
plt.scatter(df.area,df.price)
#Generate linear regression
plt.plot(df.area,reg.predict(df[['area']]))

# %%
#Given the area data
d=pd.read_csv('areas.csv')
d.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
#Predict the home price
p=reg.predict(d)

# %%
#Add the price column to the dataframe
d['prices']=p
#Save it back
d.to_csv('prediction.csv',index=False)

# %%
df1=pd.read_csv('canada_per_capita_income.csv')
df1.tail()
# Out:
#     year  per capita income (US$)
# 42  2012              42665.25597
# 43  2013              42676.46837
# 44  2014              41039.89360
# 45  2015              35175.18898
# 46  2016              34229.19363

# %%
# %matplotlib inline
plt.scatter(df1[['year']],df1[['per capita income (US$)']])
plt.xlabel('year')
plt.ylabel('income')

# %%
reg1=linear_model.LinearRegression()

# %%
reg1.fit
# Out:
# <bound method LinearRegression.fit of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)>

# %%
reg1.fit(df1[['year']],df1[['per capita income (US$)']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg1.coef_
# Out:
# array([[ 828.46507522]])

# %%
reg1.intercept_
# Out:
# array([-1632210.75785546])

# %%
reg1.predict(2018)
# Out:
# array([[ 39631.76394397]])

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import linear_model

# %%
df=pd.read_csv('.csv')
df.head()
reg=LinearRegression()
reg.fit(df[['area']],df[['price']])
